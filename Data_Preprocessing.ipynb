# %%
import pandas as pd
import xml.etree.ElementTree as ET
import os
import glob

train_df = pd.DataFrame(columns=['FileName', 'XMin', 'XMax', 'YMin', 'YMax', 'ClassName'])

# data_path = "Dataset/train/annotation"
# annotation_data = os.listdir(data_path)

# print(annotation_data)
# print(annotation_data)
for data in glob.glob("Dataset/train/annotation/*.xml"):
    tree = ET.parse(data)
    root = tree.getroot()
    print("1")
    # retrieve all <bndbox>
    bndbox_values = []
    filename = root.find('filename').text
    print(filename)
    name = root.find('object/name').text
    if name is None:
        continue
    print(name)
    for bndbox in root.findall('object/bndbox'):
        xmin = int(bndbox.find('xmin').text)
        ymin = int(bndbox.find('ymin').text)
        xmax = int(bndbox.find('xmax').text)
        ymax = int(bndbox.find('ymax').text)
        bndbox_values.append([xmin,ymin,xmax,ymax])

    values = [[filename, bndbox_values[0][0], bndbox_values[0][2], bndbox_values[0][1], bndbox_values[0][3], name]]

    train_df = pd.concat([train_df, pd.DataFrame(values, columns=['FileName', 'XMin', 'XMax', 'YMin', 'YMax', 'ClassName'])], ignore_index=True)
    print(train_df)
train_df.to_csv("train.csv")


###Thank you for your carefully reviewing my implement file. I think to communicate via upwork is not comfortable. So I suggest to talk via Whatsapp or Skype. My Skype username is:live:.cid.48e7d80849c26b6f, And whatsapp number is +18105228634. Thank you again!!!###
# Out:
# 1
# kicking_ 2_000342.jpg
# kicking
#                 FileName XMin  XMax YMin  YMax ClassName
# 0  kicking_ 2_000342.jpg  655  1095  563  1000   kicking
# 1
# kicking_ 2_000345.jpg
# kicking
#                 FileName XMin  XMax YMin  YMax ClassName
# 0  kicking_ 2_000342.jpg  655  1095  563  1000   kicking
# 1  kicking_ 2_000345.jpg  684  1186  576   995   kicking
# 1
# kicking_ 2_000348.jpg
# kicking
#                 FileName XMin  XMax YMin  YMax ClassName
# 0  kicking_ 2_000342.jpg  655  1095  563  1000   kicking
# 1  kicking_ 2_000345.jpg  684  1186  576   995   kicking
# 2  kicking_ 2_000348.jpg  697  1240  613   991   kicking
# 1
# kicking_ 2_000354.jpg
# kicking
#                 FileName XMin  XMax YMin  YMax ClassName
# 0  kicking_ 2_000342.jpg  655  1095  563  1000   kicking
# 1  kicking_ 2_000345.jpg  684  1186  576   995   kicking
# 2  kicking_ 2_000348.jpg  697  1240  613   991   kicking
# 3  kicking_ 2_000354.jpg  666  1214  611  1008   kicking
# 1
# ...

# %%
import pandas as pd
import xml.etree.ElementTree as ET
import os
import glob

train_df = pd.DataFrame(columns=['FileName', 'XMin', 'XMax', 'YMin', 'YMax', 'ClassName'])

# data_path = "Dataset/train/annotation"
# annotation_data = os.listdir(data_path)

# print(annotation_data)
# print(annotation_data)
for data in glob.glob("Dataset/validation/annotation/*.xml"):
    tree = ET.parse(data)
    root = tree.getroot()
    print("1")
    # retrieve all <bndbox>
    bndbox_values = []
    filename = root.find('filename').text
    print(filename)
    name = root.find('object/name').text
    if name is None:
        continue
    print(name)
    for bndbox in root.findall('object/bndbox'):
        xmin = int(bndbox.find('xmin').text)
        ymin = int(bndbox.find('ymin').text)
        xmax = int(bndbox.find('xmax').text)
        ymax = int(bndbox.find('ymax').text)
        bndbox_values.append([xmin,ymin,xmax,ymax])

    values = [[filename, bndbox_values[0][0], bndbox_values[0][2], bndbox_values[0][1], bndbox_values[0][3], name]]

    train_df = pd.concat([train_df, pd.DataFrame(values, columns=['FileName', 'XMin', 'XMax', 'YMin', 'YMax', 'ClassName'])], ignore_index=True)
    print(train_df)
train_df.to_csv("test.csv")
# Out:
# 1
# kicking_ 2_000003.jpg
# kicking
#                 FileName XMin XMax YMin  YMax ClassName
# 0  kicking_ 2_000003.jpg  512  903  626  1021   kicking
# 1
# kicking_ 2_000006.jpg
# kicking
#                 FileName XMin XMax YMin  YMax ClassName
# 0  kicking_ 2_000003.jpg  512  903  626  1021   kicking
# 1  kicking_ 2_000006.jpg  581  964  597  1021   kicking
# 1
# kicking_ 2_000011.jpg
# kicking
#                 FileName XMin  XMax YMin  YMax ClassName
# 0  kicking_ 2_000003.jpg  512   903  626  1021   kicking
# 1  kicking_ 2_000006.jpg  581   964  597  1021   kicking
# 2  kicking_ 2_000011.jpg  536  1090  554  1021   kicking
# 1
# kicking_ 2_000015.jpg
# kicking
#                 FileName XMin  XMax YMin  YMax ClassName
# 0  kicking_ 2_000003.jpg  512   903  626  1021   kicking
# 1  kicking_ 2_000006.jpg  581   964  597  1021   kicking
# 2  kicking_ 2_000011.jpg  536  1090  554  1021   kicking
# 3  kicking_ 2_000015.jpg  547  1186  593  1039   kicking
# 1
# ...

# %%
train_df = pd.read_csv('train.csv')

# for training
with open("annotation.txt", "w+") as f:
  for idx, row in train_df.iterrows():
    #   print(idx)
    #   print("--------------------------------------------------")
    #   print(row)
      height = 1080
      width = 1920
      x1 = int(row['XMin'] * width)
      x2 = int(row['XMax'] * width)
      y1 = int(row['YMin'] * height)
      y2 = int(row['YMax'] * height)
      
      google_colab_file_path = 'drive/My Drive/Human_Detection/train'
      fileName = os.path.join(google_colab_file_path, row['FileName'])
      className = row['ClassName']
      f.write(fileName + ',' + str(x1) + ',' + str(y1) + ',' + str(x2) + ',' + str(y2) + ',' + className + '\n')

# %%
train_df = pd.read_csv('test.csv')

# for training
with open("test_annotation.txt", "w+") as f:
  for idx, row in train_df.iterrows():
    
    #   print(idx)
    #   print("--------------------------------------------------")
    #   print(row)
      height = 1080
      width = 1920
      x1 = int(row['XMin'] * width)
      x2 = int(row['XMax'] * width)
      y1 = int(row['YMin'] * height)
      y2 = int(row['YMax'] * height)
      
      google_colab_file_path = 'drive/My Drive/Human_Detection/test'
      fileName = os.path.join(google_colab_file_path, row['FileName'])
      className = row['ClassName']
      f.write(fileName + ',' + str(x1) + ',' + str(y1) + ',' + str(x2) + ',' + str(y2) + ',' + className + '\n')
